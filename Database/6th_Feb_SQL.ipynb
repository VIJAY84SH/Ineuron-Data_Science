# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost", user = "root", passwd = "mysql")

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sudh',),
#  ('sys',),
#  ('world',)]

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1004-C407
#
#  Directory of C:\Users\vijay\OneDrive\Desktop\Data_Science\Python_Classes
#
# 03/23/2022  12:29 PM    <DIR>          .
# 03/23/2022  12:29 PM    <DIR>          ..
# 03/21/2022  07:17 PM    <DIR>          .ipynb_checkpoints
# 02/16/2022  12:24 PM    <DIR>          __pycache__
# 02/02/2022  02:48 PM            22,955 15th_Jan.ipynb
# 02/01/2022  10:16 PM            15,272 15th_jan_Logging.ipynb
# 01/24/2022  01:26 PM            53,959 19Th_Dec_Fun_Practice_Prob.ipynb
# 02/07/2022  08:38 PM            13,415 22_Jan_22.ipynb
# 02/16/2022  12:22 PM            15,574 23_jan_01.ipynb
# 02/16/2022  12:39 PM             2,640 23_jan_02.ipynb
# 02/23/2022  12:20 PM            17,068 29_jan.ipynb
# 03/20/2022  11:22 AM            69,008 5th_feb_SQL.ipynb
# 03/23/2022  12:29 PM           558,274 6th_Feb_SQL.ipynb
# 01/13/2022  12:46 PM            30,008 8th_Jan_22.ipynb
# ...

# %%
cursor.execute("select * from sudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select col1, col5, col10 from sudh.glassdata")

# %%
# select col as we want also as per you are giving the name 
#for select colnm as per that it will show the column sequence

# %%
cursor.fetchall()
# Out:
# [(6, 1.1, 0.0),
#  (6, 1.1, 0.0),
#  (2, 1.1, 0.0),
#  (6, 1.1, 0.0),
#  (2, 1.36, 0.0),
#  (3, 1.54, 0.0),
#  (5, 1.24, 0.0),
#  (6, 1.62, 0.26),
#  (7, 1.14, 0.0),
#  (8, 1.05, 0.0),
#  (9, 1.37, 0.0),
#  (10, 1.36, 0.11),
#  (11, 1.56, 0.24),
#  (12, 1.27, 0.0),
#  (13, 1.4, 0.24),
#  (14, 1.27, 0.17),
#  (15, 1.31, 0.0),
#  (16, 1.23, 0.0),
#  (17, 1.16, 0.0),
#  (18, 0.89, 0.0),
#  (19, 1.18, 0.0),
#  (20, 1.69, 0.07),
#  (21, 1.49, 0.19),
#  (22, 0.29, 0.0),
#  (23, 1.29, 0.0),
#  (24, 1.35, 0.0),
#  (25, 1.15, 0.0),
#  (26, 1.21, 0.0),
#  (27, 1.41, 0.0),
#  (28, 1.33, 0.0),
#  (29, 1.43, 0.0),
#  (30, 1.28, 0.0),
#  (31, 1.3, 0.14),
#  (32, 1.14, 0.0),
#  (33, 1.23, 0.22),
#  (34, 1.38, 0.06),
#  (35, 1.34, 0.0),
#  (36, 1.21, 0.0),
#  (37, 1.32, 0.0),
#  (38, 1.35, 0.0),
#  (39, 0.47, 0.0),
#  (40, 0.47, 0.0),
#  (41, 1.12, 0.0),
#  (42, 1.2, 0.0),
#  (43, 1.33, 0.0),
#  (44, 0.72, 0.0),
#  (45, 1.19, 0.3),
#  (46, 1.35, 0.0),
#  (47, 1.18, 0.16),
#  (48, 0.71, 0.1),
# ...

# %%
# select colum 1 value is equal to 1

# %%
cursor.execute("select * from sudh.glassdata where col1 = 4")

# %%
cursor.fetchall()
# Out:
# [(4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1)]

# %%
cursor.execute("select * from sudh.glassdata where col1 = 4 and col11 = 0")

# %%
cursor.fetchall()
# Out:
# []

# %% [markdown]
# # Delete Operation

# %%
cursor.execute("delete from sudh.glassdata where col1 = 4")

# %%
cursor.execute("select * from sudh.glassdata where col1 = 4")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from sudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
# ...

# %% [markdown]
# # Update operation

# %%
cursor.execute("UPDATE sudh.glassdata SET col1 = 6, col2 = 8 where col1 = 1 ")

# %%
mydb.commit()

# %%
cursor.execute("select * from sudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select col1, count(col1) from sudh.glassdata group by col1 order by col1")

# %%
cursor.fetchall()
# Out:
# [(2, 6),
#  (3, 5),
#  (5, 5),
#  (6, 12),
#  (7, 5),
#  (8, 5),
#  (9, 5),
#  (10, 5),
#  (11, 5),
#  (12, 5),
#  (13, 5),
#  (14, 5),
#  (15, 5),
#  (16, 5),
#  (17, 5),
#  (18, 5),
#  (19, 5),
#  (20, 5),
#  (21, 5),
#  (22, 5),
#  (23, 5),
#  (24, 5),
#  (25, 5),
#  (26, 5),
#  (27, 5),
#  (28, 5),
#  (29, 5),
#  (30, 5),
#  (31, 5),
#  (32, 5),
#  (33, 5),
#  (34, 5),
#  (35, 5),
#  (36, 5),
#  (37, 5),
#  (38, 5),
#  (39, 5),
#  (40, 5),
#  (41, 5),
#  (42, 5),
#  (43, 5),
#  (44, 5),
#  (45, 5),
#  (46, 5),
#  (47, 5),
#  (48, 5),
#  (49, 5),
#  (50, 5),
#  (51, 5),
#  (52, 5),
#  (53, 5),
#  (54, 5),
#  (55, 5),
#  (56, 5),
#  (57, 5),
#  (58, 5),
#  (59, 5),
#  (60, 5),
#  (61, 5),
#  (62, 5),
#  (63, 5),
#  (64, 5),
#  (65, 5),
#  (66, 5),
#  (67, 5),
#  (68, 5),
#  (69, 5),
#  (70, 5),
#  (71, 5),
#  (72, 5),
#  (73, 5),
#  (74, 5),
#  (75, 5),
#  (76, 5),
#  (77, 5),
#  (78, 5),
#  (79, 5),
#  (80, 5),
#  (81, 5),
#  (82, 5),
#  (83, 5),
#  (84, 5),
#  (85, 5),
# ...

# %%
cursor.execute("select * from sudh.ineuron")

# %%
cursor.fetchall()
# Out:
# [(1234, 'vijay', 'patil', 123, 'fsds'),
#  (1234, 'vijay', 'patil', 123, 'fsds'),
#  (1234567, 'vijaypatil', 'patilvijay', 123123, 'fsdssds'),
#  (1234567, 'vijaypatil', 'patilvijay', 123123, 'fsdssds'),
#  (1234, 'vijaypatil', 'patilvijay', 123123, 'fsdssds'),
#  (564576, 'suhghfdh', 'kumar', 2344323, 'FSDS'),
#  (1234, 'vijay', 'patil', 123, 'fsds'),
#  (1234, 'vijaypatil', 'patilvijay', 123123, 'fsdssds')]

# %%
cursor.execute("select classname from sudh.ineuron")

# %%
cursor.fetchall()
# Out:
# [('fsds',),
#  ('fsds',),
#  ('fsdssds',),
#  ('fsdssds',),
#  ('fsdssds',),
#  ('FSDS',),
#  ('fsds',),
#  ('fsdssds',)]

# %%
cursor.execute("select count(classname) from sudh.ineuro")

# %%
cursor.fetchall()
# Out:
# [(8,)]

# %%
cursor.execute("select count(*),classname from sudh.ineuron where classname = 'fsds' ")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sudh',),
#  ('sys',),
#  ('world',)]

# %%
cursor.execute('select col1,col2, col11 from sudh.glassdata where col1 = 11 or col11 = 2')

# %%
cursor.fetchall()
# Out:
# [(11, 1.51571, 1),
#  (71, 1.51574, 2),
#  (72, 1.51848, 2),
#  (73, 1.51593, 2),
#  (74, 1.51631, 2),
#  (75, 1.51596, 2),
#  (76, 1.5159, 2),
#  (77, 1.51645, 2),
#  (78, 1.51627, 2),
#  (79, 1.51613, 2),
#  (80, 1.5159, 2),
#  (81, 1.51592, 2),
#  (82, 1.51593, 2),
#  (83, 1.51646, 2),
#  (84, 1.51594, 2),
#  (85, 1.51409, 2),
#  (86, 1.51625, 2),
#  (87, 1.51569, 2),
#  (88, 1.51645, 2),
#  (89, 1.51618, 2),
#  (90, 1.5164, 2),
#  (91, 1.51841, 2),
#  (92, 1.51605, 2),
#  (93, 1.51588, 2),
#  (94, 1.5159, 2),
#  (95, 1.51629, 2),
#  (96, 1.5186, 2),
#  (97, 1.51841, 2),
#  (98, 1.51743, 2),
#  (99, 1.51689, 2),
#  (100, 1.51811, 2),
#  (101, 1.51655, 2),
#  (102, 1.5173, 2),
#  (103, 1.5182, 2),
#  (104, 1.52725, 2),
#  (105, 1.5241, 2),
#  (106, 1.52475, 2),
#  (107, 1.53125, 2),
#  (108, 1.53393, 2),
#  (109, 1.52222, 2),
#  (110, 1.51818, 2),
#  (111, 1.52664, 2),
#  (112, 1.52739, 2),
#  (113, 1.52777, 2),
#  (114, 1.51892, 2),
#  (115, 1.51847, 2),
#  (116, 1.51846, 2),
# ...

# %%
cursor.execute("select * from sudh.glassdata where col2 like '1.515%' ")

# %%
cursor.fetchall()
# Out:
# [(6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
# ...

# %%
cursor.execute("select * from sudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from sudh.glassdata order by col2 ")

# %%
cursor.fetchall()
# Out:
# [(185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (185, 1.51115, 17.38, 0.0, 0.34, 75.41, 0.0, 6.65, 0.0, 0.0, 6),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (186, 1.51131, 13.69, 3.2, 1.81, 72.81, 1.76, 5.43, 1.19, 0.0, 7),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
#  (57, 1.51215, 12.99, 3.47, 1.12, 72.98, 0.62, 8.35, 0.0, 0.31, 1),
# ...

# %%
cursor.execute("select * from sudh.glassdata order by col2 desc")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
# ...

# %%
cursor.execute("select * from(select * from sudh.glassdata where col1 > 112) as sudh where col11 = 3 ")

# %%
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute("select * from sudh.glassdata group by col1 having count(col1) >1 ")

# %% [raw]
# cursor.fetchall()

# %%
cursor.execute("select * from sudh.glassdata where col1 = 6")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select * from sudh.glassdata where count(col1) > 2")
